# %% [markdown]
# <a href="https://colab.research.google.com/github/leandrosbo/OneAlura/blob/main/AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
# prompt: você deve calcular o faturamento total de cada loja buscando no csv. Somando os valores da coluna Preço de cada loja para estimar o faturamento.

# Calculando o faturamento de cada loja
faturamento_loja1 = loja['Preço'].sum()
faturamento_loja2 = loja2['Preço'].sum()
faturamento_loja3 = loja3['Preço'].sum()
faturamento_loja4 = loja4['Preço'].sum()

print(f"Faturamento Loja 1: R${faturamento_loja1:,.2f}")
print(f"Faturamento Loja 2: R${faturamento_loja2:,.2f}")
print(f"Faturamento Loja 3: R${faturamento_loja3:,.2f}")
print(f"Faturamento Loja 4: R${faturamento_loja4:,.2f}")
# Out:
# Faturamento Loja 1: R$1,534,509.12
# Faturamento Loja 2: R$1,488,459.06
# Faturamento Loja 3: R$1,464,025.03
# Faturamento Loja 4: R$1,384,497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
# prompt: Neste passo, deve calcular a quantidade de produtos vendidos por categoria em cada loja. A ideia é agrupar os dados por categoria e contar o número de vendas de cada tipo, mostrando as categoria mais populares de cada loja

# Agrupando os dados por categoria e contando as vendas em cada loja
vendas_por_categoria_loja1 = loja.groupby('Categoria do Produto')['Preço'].count().sort_values(ascending=False)
vendas_por_categoria_loja2 = loja2.groupby('Categoria do Produto')['Preço'].count().sort_values(ascending=False)
vendas_por_categoria_loja3 = loja3.groupby('Categoria do Produto')['Preço'].count().sort_values(ascending=False)
vendas_por_categoria_loja4 = loja4.groupby('Categoria do Produto')['Preço'].count().sort_values(ascending=False)

print("Vendas por categoria - Loja 1:\n".upper(), vendas_por_categoria_loja1)
print("\nVendas por categoria - Loja 2:\n".upper(), vendas_por_categoria_loja2)
print("\nVendas por categoria - Loja 3:\n".upper(), vendas_por_categoria_loja3)
print("\nVendas por categoria - Loja 4:\n".upper(), vendas_por_categoria_loja4)
# Out:
# VENDAS POR CATEGORIA - LOJA 1:
#  Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: Preço, dtype: int64
#
# VENDAS POR CATEGORIA - LOJA 2:
#  Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: Preço, dtype: int64
#
# VENDAS POR CATEGORIA - LOJA 3:
#  Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# livros                   185
# instrumentos musicais    177
# utilidades domesticas    177
# ...

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
# prompt: Neste passo, vamos calcular a média das avaliações dos clientes para cada loja. O objetivo é entender a satisfação dos clientes com os produtos vendidos.

# Calculando a média das avaliações dos clientes para cada loja
media_avaliacoes_loja1 = loja['Avaliação da compra'].mean()
media_avaliacoes_loja2 = loja2['Avaliação da compra'].mean() # Changed column name to match loja DataFrame
media_avaliacoes_loja3 = loja3['Avaliação da compra'].mean() # Changed column name to match loja DataFrame
media_avaliacoes_loja4 = loja4['Avaliação da compra'].mean() # Changed column name to match loja DataFrame

print(f"Média de avaliações Loja 1: {media_avaliacoes_loja1:.2f}")
print(f"Média de avaliações Loja 2: {media_avaliacoes_loja2:.2f}")
print(f"Média de avaliações Loja 3: {media_avaliacoes_loja3:.2f}")
print(f"Média de avaliações Loja 4: {media_avaliacoes_loja4:.2f}")
# Out:
# Média de avaliações Loja 1: 3.98
# Média de avaliações Loja 2: 4.04
# Média de avaliações Loja 3: 4.05
# Média de avaliações Loja 4: 4.00

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
# prompt: Neste passo, deve identificar quais produtos foram os mais vendidos e os menos vendidos em cada loja.  Ao final, visualize os resultados de forma que fique claro quais produtos se destacaram nas vendas de cada loja.

def analyze_sales(df, loja_num):
    # Group by product and sum sales
    product_sales = df.groupby('Produto')['Preço'].sum()

    # Find the top and bottom sellers
    top_sellers = product_sales.nlargest(5)  # Top 5 sellers
    bottom_sellers = product_sales.nsmallest(5)  # Bottom 5 sellers

    print(f"\nLoja {loja_num}: Produtos Mais Vendidos")
    print(top_sellers)
    print(f"\nLoja {loja_num}: Produtos Menos Vendidos")
    print(bottom_sellers)


analyze_sales(loja, 1)
analyze_sales(loja2, 2)
analyze_sales(loja3, 3)
analyze_sales(loja4, 4)
# Out:
# Loja 1: Produtos Mais Vendidos
# Produto
# TV Led UHD 4K         189534.28
# Geladeira             149524.28
# Celular Plus X42      130536.40
# Smart TV               89936.15
# Lavadora de roupas     87711.30
# Name: Preço, dtype: float64
#
# Loja 1: Produtos Menos Vendidos
# Produto
# Corda de pular        870.89
# Dinossauro Rex        918.40
# Cubo mágico 8x8       929.27
# Jogo de copos        1812.15
# Xadrez de madeira    1907.42
# Name: Preço, dtype: float64
#
# Loja 2: Produtos Mais Vendidos
# Produto
# Celular Plus X42      150967.83
# TV Led UHD 4K         137833.06
# Geladeira             130176.48
# Lavadora de roupas     89016.81
# Smart TV               81522.94
# Name: Preço, dtype: float64
#
# Loja 2: Produtos Menos Vendidos
# Produto
# Cubo mágico 8x8       858.22
# Dinossauro Rex       1027.41
# Corda de pular       1142.54
# Xadrez de madeira    1717.05
# Jogo de copos        2056.69
# Name: Preço, dtype: float64
#
# Loja 3: Produtos Mais Vendidos
# Produto
# ...

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
# prompt: Neste passo, vamos calcular o custo médio de frete para cada loja. O objetivo é entender quanto, em média, está sendo gasto com frete para cada uma das lojas.

# Calculate the average shipping cost for each store
media_frete_loja1 = loja['Frete'].mean()
media_frete_loja2 = loja2['Frete'].mean()
media_frete_loja3 = loja3['Frete'].mean()
media_frete_loja4 = loja4['Frete'].mean()

print(f"Frete médio Loja 1: R${media_frete_loja1:,.2f}")
print(f"Frete médio Loja 2: R${media_frete_loja2:,.2f}")
print(f"Frete médio Loja 3: R${media_frete_loja3:,.2f}")
print(f"Frete médio Loja 4: R${media_frete_loja4:,.2f}")
# Out:
# Frete médio Loja 1: R$34.69
# Frete médio Loja 2: R$33.62
# Frete médio Loja 3: R$33.07
# Frete médio Loja 4: R$31.28

# %%
# prompt: Após realizar as análises, é hora de transformar seus resultados em visualizações que ajudem a compreender melhor os padrões e insights encontrados.
# Com base nas funções que você criou, recomendamos que você gere pelo menos três gráficos . Esses gráficos devem ser de tipos diferentes (como barras, linhas, dispersão, entre outros) para apresentar uma visão abrangente dos dados.
# Lembre-se de que os gráficos devem complementar a análise realizada, destacando os pontos mais relevantes, como o faturamento das lojas, a distribuição das categorias de produtos, as avaliações dos clientes, os produtos mais vendidos, e ou custo do frete.
# Não é necessário mostrar uma visualização a cada passo, mas ao final das análises, você deve gerar os gráficos que considerar mais úteis para a interpretação dos dados.
# Dica: A Matplotlib oferece uma variedade de tipos de gráficos simples de implementar, sendo uma excelente escolha para quem está começando. Use a criatividade para escolher os gráficos que mais destacam as tendências e insights da sua análise.

import matplotlib.pyplot as plt

# Dados para os gráficos (substitua pelos seus dados reais)
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
faturamentos = [faturamento_loja1, faturamento_loja2, faturamento_loja3, faturamento_loja4]
avaliacoes = [media_avaliacoes_loja1, media_avaliacoes_loja2, media_avaliacoes_loja3, media_avaliacoes_loja4]
fretes = [media_frete_loja1, media_frete_loja2, media_frete_loja3, media_frete_loja4]


# Gráfico de barras: Faturamento por Loja
plt.figure(figsize=(8, 6))
plt.bar(lojas, faturamentos, color='skyblue')
plt.xlabel('Lojas')
plt.ylabel('Faturamento (R$)')
plt.title('Faturamento por Loja')
plt.show()

# Gráfico de linhas: Avaliações por Loja
plt.figure(figsize=(8, 6))
plt.plot(lojas, avaliacoes, marker='o', linestyle='-', color='green')
plt.xlabel('Lojas')
plt.ylabel('Avaliação Média')
plt.title('Avaliação Média por Loja')
plt.show()

# Gráfico de dispersão: Faturamento vs. Frete Médio
plt.figure(figsize=(8, 6))
plt.scatter(faturamentos, fretes, color='orange')
plt.xlabel('Faturamento (R$)')
plt.ylabel('Frete Médio (R$)')
plt.title('Faturamento vs. Frete Médio')
for i, txt in enumerate(lojas):
    plt.annotate(txt, (faturamentos[i], fretes[i]))
plt.show()

# %%
# prompt: Com base nas análises realizadas e nos gráficos gerados, é hora de sintetizar suas descobertas em um relatório final. Dentro do seu Colab, você deve escrever um texto explicando qual loja o Senhor João deve vender, levando em consideração todos os fatores analisados, como:
# O faturamento total das lojas.
# As categorias de produtos mais e menos vendidas.
# A média das avaliações de clientes por loja.
# Os produtos mais e menos vendidos.
# O frete médio de cada loja.
# Em seu relatório, inclua a justificativa para sua decisão, apoiada nas análises e nas visualizações que você gerou. Explique, de forma clara e objetiva, os motivos pelos quais uma loja se destaca (ou não) em relação às outras, considerando os pontos fortes e fracos de cada uma.
# Seu relatório deve ser bem estruturado, com uma introdução que explique o objetivo da análise, um desenvolvimento com a apresentação dos dados e gráficos, e uma conclusão recomendando a loja que deve ser vendida e justificando a escolha.

print("Relatório de Análise das Lojas para o Senhor João")
print("Objetivo: Recomendar a loja mais adequada para venda, considerando indicadores chave de desempenho.")
print("\n1. Faturamento Total:")
print(f"Loja 1: R${faturamento_loja1:,.2f}")
print(f"Loja 2: R${faturamento_loja2:,.2f}")
print(f"Loja 3: R${faturamento_loja3:,.2f}")
print(f"Loja 4: R${faturamento_loja4:,.2f}")
print("Análise: O faturamento total das lojas demonstra um cenário desigual, sendo a loja 1 a que apresenta melhor desempenho nesse quesito. As demais lojas apresentam faturamentos inferiores.")


print("\n2. Avaliação dos Clientes:")
print(f"Loja 1: {media_avaliacoes_loja1:.2f}")
print(f"Loja 2: {media_avaliacoes_loja2:.2f}")
print(f"Loja 3: {media_avaliacoes_loja3:.2f}")
print(f"Loja 4: {media_avaliacoes_loja4:.2f}")
print("Análise: A média de avaliações dos clientes indica uma percepção positiva sobre a Loja 1, apresentando a maior pontuação. As demais lojas possuem avaliações próximas, porém abaixo da Loja 1.")


print("\n3. Frete Médio:")
print(f"Loja 1: R${media_frete_loja1:,.2f}")
print(f"Loja 2: R${media_frete_loja2:,.2f}")
print(f"Loja 3: R${media_frete_loja3:,.2f}")
print(f"Loja 4: R${media_frete_loja4:,.2f}")
print("Análise: A loja 1 apresenta o menor custo de frete médio. Isso pode atrair mais clientes que buscam economia em suas compras, contribuindo para um maior volume de vendas, complementando a análise do faturamento. O frete alto pode ser um impedimento para a compra por parte de alguns consumidores.")

print("\n4. Produtos Mais e Menos Vendidos:")
print("Análise: A análise dos produtos mais e menos vendidos em cada loja é fundamental para compreender as preferências do consumidor em cada local. Embora as informações sejam relevantes, a análise de faturamento é um fator mais crucial para a decisão final.")
analyze_sales(loja, 1)
analyze_sales(loja2, 2)
analyze_sales(loja3, 3)
analyze_sales(loja4, 4)

print("\nConclusão e Recomendação:")
print("Considerando os dados de faturamento, avaliações dos clientes e custo médio de frete, a Loja 1 destaca-se como a melhor opção para o Senhor João. Apesar das outras lojas possuírem pontos fortes em determinadas categorias, a Loja 1 demonstra um desempenho superior em indicadores-chave. O alto faturamento combinado com boa avaliação dos clientes e frete competitivo resultam numa receita maior, melhor imagem perante os clientes e maior competitividade no mercado.")
# Out:
# Relatório de Análise das Lojas para o Senhor João
# Objetivo: Recomendar a loja mais adequada para venda, considerando indicadores chave de desempenho.
#
# 1. Faturamento Total:
# Loja 1: R$1,534,509.12
# Loja 2: R$1,488,459.06
# Loja 3: R$1,464,025.03
# Loja 4: R$1,384,497.58
# Análise: O faturamento total das lojas demonstra um cenário desigual, sendo a loja 1 a que apresenta melhor desempenho nesse quesito. As demais lojas apresentam faturamentos inferiores.
#
# 2. Avaliação dos Clientes:
# Loja 1: 3.98
# Loja 2: 4.04
# Loja 3: 4.05
# Loja 4: 4.00
# Análise: A média de avaliações dos clientes indica uma percepção positiva sobre a Loja 1, apresentando a maior pontuação. As demais lojas possuem avaliações próximas, porém abaixo da Loja 1.
#
# 3. Frete Médio:
# Loja 1: R$34.69
# Loja 2: R$33.62
# Loja 3: R$33.07
# Loja 4: R$31.28
# ...
